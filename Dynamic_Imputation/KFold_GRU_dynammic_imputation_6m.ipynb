# %% [markdown]
# # Dynamic mputation RNN
# ### Prediction Imputation
#
# - For this model we do not mask the training set's missing instances. We impute them.
#
# - We do, however, perform masking for the teting data evaluation.
#
# - Imputation with X_train, y_train
#     - Divide into X_full and X_nan; y_full and y_nan
#     - Use X_full and y_full to impute for X_nan and y_nan
# - X_test, y_test
#     - Impute with model learned from training data

# %% [markdown]
# # Updates
# - Remove all test operations
# - mask_list.append((train, test)) went to mask_list.append(train)

# %% [markdown]
# ### Functions

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
import tensorflow as tf
import sklearn as sk
from matplotlib import pyplot as plt
from sklearn.model_selection import StratifiedKFold, KFold

def select_columns(col_list, n_months):
    """
    Takes in a list of column names and number of visits starting at 0.
    Returns column list time-stepped and dovetailed.
    """ 
    return dovetail_names(*[time_step_names(i, n_months) for i in col_list])
        
def time_step_names(name, n_months):

    return [(name + '_%d' % (j+1)) for j in range(-1,n_months*6, 6)]

def dovetail_names(*kwargs):
    """
    Dovetails column names across time slices cccording to preset order.
    """
    zipped = zip(*kwargs)
    l = []
   
    for i in zipped:
        
        for j in i:
            
            l.append(j)
            
    return l

def reshape_data(X, y, n_time_steps, n_features = 115):  
    
    X_reshaped = X.values.reshape(-1, n_time_steps, n_features)
    y_reshaped = y.values.reshape(-1, n_time_steps, 1)
    print("X reshaped is " + str(X_reshaped.shape))
    print("y reshaped is " + str(y_reshaped.shape))

    y = y_reshaped.astype(float)
    X = X_reshaped.astype(float)
    
    print(X.shape, y.shape)
    return X, y

def provide_data(X,y,roll,n_features=115):
 
    X = X.iloc[:,:n_features*roll]
    y = y.iloc[:,:roll]

    y_full = y.dropna()

    mask = X.index.isin(y_full.index.tolist())

    X_full = X[mask]

    y_nan = y[~mask]
    X_nan = X[~mask]
    
    print('NaN')
    X_nan, y_nan = reshape_data(X_nan, y_nan, roll)
    print('Full')
    X_full, y_full = reshape_data(X_full, y_full, roll)
    
    return X_full, X_nan, y_full, y_nan, mask


def provide_all_data(X,y,roll):
 
    X = X.iloc[:,:n_features*roll]
    y = y.iloc[:,:roll]

    X_all, y_all = reshape_data(X, y, roll)
    
    return X_all, y_all
    
def prepare_for_mask(X,y):
    
    for i in range(y.shape[0]):
        for j in range(y.shape[1]):
            if np.isnan(y[i][j][0]) or (y[i][j] == -99):

                X[i][j] = -99
                y[i][j] = -99
                
    return X,y
# Out:
# /Users/matiasberretta/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Keras Callbacks

# %%
weight_file_path = "weights/my_model_weights_6m|6m.h5"
final_file_path = "final_weights/my_model_weights_6m|6m.h5"
best_file_path = "best/best_weights_6m|6m.hdf5"

# %%
from keras import callbacks
import keras.layers as L
import keras.models as M
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error as mse

# reduce learning rate on plateau
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                               patience=5, min_lr=0.001)

# stop training if there isn't a significant improvement in the course of 5 epochs
early_stopping = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, 
                              patience=5, verbose=0, mode='auto', 
                              baseline=None, restore_best_weights=True)

# model check point
model_checkpoint = ModelCheckpoint(best_file_path, monitor='val_loss', 
                                   verbose=1, 
                                   save_best_only=True, 
                                   mode='min')

callbacks_list = [reduce_lr, early_stopping]
callbacks_list_final = [reduce_lr, early_stopping, model_checkpoint]
# Out:
# Using TensorFlow backend.

# %%
def generate_initial_predictions(n_time_steps, X_train, X_test, y_train, y_test, n_inputs=115):
    
    threshold = len(y_train.columns)
    print("TRAIN")
    X_full_train, X_nan_train, y_full_train, y_nan_train, mask_train = provide_data(X_train, y_train, n_time_steps)
    print("TEST")
    X_full_test, X_nan_test, y_full_test, y_nan_test, mask_test = provide_data(X_test, y_test, n_time_steps)
    
    # This is irrelevant because "full" data sets contain no missing values to mask
    masked_X_full_test, masked_y_full_test = prepare_for_mask(X_full_test, y_full_test)
    masked_X_full_train, masked_y_full_train = prepare_for_mask(X_full_train, y_full_train)
    
    K.clear_session()
    
    m = M.Sequential()
    m.add(L.Masking(mask_value=-99, input_shape=(n_time_steps, n_inputs)))
    m.add(L.GRU(128, return_sequences=True))
    m.add(L.Dense(1, activation='relu'))
    m.compile(optimizer = 'nadam', loss = 'mean_absolute_error')

    if n_time_steps > 1:
        
        # load weights from previous model to establish continuity 
        m.load_weights(weight_file_path)
    
    history = m.fit(masked_X_full_train, masked_y_full_train, 
                    validation_split=0.2,
                    batch_size = masked_X_full_train.shape[0], # batch size == size of the training data 
                    epochs=1, 
                    shuffle=True,
                    callbacks = callbacks_list)
        
    m.save_weights(weight_file_path) # save weights 
    
    # Predict for unknown values of training and testing data
    # Using train data with known targets, I train a model to predict for missing values
    # In both training and testing data 
    # But for the testing data, I only impute the X feature space 
    
    m_pred_train = pd.Series(np.array([x[0] for x in m.predict(X_nan_train)]).flatten(),
                             index = y_train[~mask_train].index)
    
    # redundant but also helps me known which values to update for test data feature space
    m_pred_test = pd.Series(np.array([x[0] for x in m.predict(X_nan_test)]).flatten(),
                           index = y_test[~mask_test].index)
    
    # In pandas the best way to update a dataframe or series
    # is with another dataframe or series with the desired index
    
    m_pred_train_y = m_pred_train.copy()
    m_pred_train_y[:] = -99
    
    y_train.iloc[:,n_time_steps-1].update(m_pred_train_y)
    
    if (n_time_steps < threshold): # when y contains an EDSS column that X does not 
        
        X_train.iloc[:,(n_inputs*(n_time_steps+1))-1].update(m_pred_train)
        # redundant but also helps me known which values to update for test data feature space
        X_test.iloc[:,(n_inputs*(n_time_steps+1))-1].update(m_pred_test)
        
    if (n_time_steps == threshold):
        m.save_weights(final_file_path)
        
    X_train_all, y_train_all = provide_all_data(X_train, y_test, n_time_steps)
    X_test_all, y_test_all = provide_all_data(X_test, y_test, n_time_steps)
    
    masked_X_train_all, masked_y_train_all = prepare_for_mask(X_train_all, y_train_all)
    masked_X_test_all, masked_y_test_all = prepare_for_mask(X_test_all, y_test_all)
    
    # predict for all values 
    # use the masking list to known which of these should be used as imputation values
    all_train_pred = m.predict(masked_X_train_all)
    all_test_pred = m.predict(masked_X_test_all)

    return X_train, X_test, y_train, y_test, all_train_pred, all_test_pred, mask_train, mask_test

# %%
def update_previous_predictions(n_time_steps, all_train_pred, all_test_pred):
    
    m_pred_train = np.array(all_train_pred[:,n_time_steps-1,:]).flatten()
    m_pred_test = np.array(all_test_pred[:,n_time_steps-1,:]).flatten()
    
    return m_pred_train, m_pred_test

# %%
# should have a way of identifying which isntances to update
def impute_previous_predictions(n_time_steps, X_train, X_test, 
                                m_pred_train, m_pred_test, mask_list, n_inputs=115):
    
    mask_train = mask_list[n_time_steps-1][0]
    mask_test = mask_list[n_time_steps-1][1]
    
    m_pred_train = pd.Series(m_pred_train[~mask_train], index = y_train[~mask_train].index)
    m_pred_test = pd.Series(m_pred_test[~mask_test], index = y_test[~mask_test].index)
    
    if n_time_steps < len(y_train.columns): # 36
        
        X_train.iloc[:,(n_inputs*(n_time_steps+1))-1].update(m_pred_train)
        X_test.iloc[:,(n_inputs*(n_time_steps+1))-1].update(m_pred_test)
    
    return X_train, X_test

# %% [markdown]
# # Import Data

# %%
X = pd.read_csv('../../../data/pre_imputation_data/X_6_months|6_months.csv', index_col = 0)
y = pd.read_csv('../../../data/pre_imputation_data/y_6_months|6_months.csv', index_col = 0)

#n_time_steps = len(y.columns)
n_features = X.columns.tolist().index("EDSS_0")+1
pot = 1
n_inputs = n_features * pot
n_units = 128
skf = KFold(n_splits=5, shuffle=True, random_state=42)
print("The input length of the training data will be", pot, "time slices, separated by 6 month intervals")
print(n_features, "featues comprise one time slice")
# Out:
# The input length of the training data will be 1 time slices, separated by 6 month intervals
# 115 featues comprise one time slice

# %%
# Drop all missing values from EDSS_0 which is our first X feature predictor
mask = X.index.isin(X['EDSS_0'].dropna().index.tolist())

X_og, y_og = X[mask], y[mask]

# %%
train_ix = []
test_ix = []
for train, test in skf.split(X_og.index):
    train_ix.append(train)
    test_ix.append(test)

# %%
def def_train_name(f_ix):
    
    X_train_name = "X_train_f" + str(f_ix + 1) + ".csv"
    y_train_name = "y_train_f" + str(f_ix + 1) + ".csv"
    X_test_name = "X_test_f" + str(f_ix + 1) + ".csv"
    y_test_name = "y_test_f" + str(f_ix + 1) + ".csv"
    
    return X_train_name, X_test_name, y_train_name, y_test_name

# %%
f_ix = 4

X_train_og, y_train_og = X_og.iloc[train_ix[f_ix], :].copy(), y_og.iloc[train_ix[f_ix], :].copy()
X_test_og, y_test_og = X_og.iloc[test_ix[f_ix], :].copy(), y_og.iloc[test_ix[f_ix], :].copy()

# %% [markdown]
# # Divide Data into Training and Testing

# %%
mask_list = []

X_train, X_test, y_train, y_test, all_train_pred, all_test_pred, mask_train, mask_test = generate_initial_predictions(1, X_train_og, X_test_og,  y_train_og, y_test_og)

mask_list.append((mask_train, mask_test)) # these tell me what values are missing in each column
# Out:
# TRAIN
# NaN
# X reshaped is (60, 1, 115)
# y reshaped is (60, 1, 1)
# (60, 1, 115) (60, 1, 1)
# Full
# X reshaped is (333, 1, 115)
# y reshaped is (333, 1, 1)
# (333, 1, 115) (333, 1, 1)
# TEST
# NaN
# X reshaped is (17, 1, 115)
# y reshaped is (17, 1, 1)
# (17, 1, 115) (17, 1, 1)
# Full
# X reshaped is (81, 1, 115)
# y reshaped is (81, 1, 1)
# (81, 1, 115) (81, 1, 1)
# Train on 266 samples, validate on 67 samples
# Epoch 1/1
# 266/266 [==============================] - 2s 8ms/step - loss: 1.7572 - val_loss: 1.0009
# X reshaped is (393, 1, 115)
# y reshaped is (98, 1, 1)
# (393, 1, 115) (98, 1, 1)
# X reshaped is (98, 1, 115)
# y reshaped is (98, 1, 1)
# (98, 1, 115) (98, 1, 1)

# %%
print("There are missing values for EDSS in the X feature space:", pd.isna(X_train['EDSS_6']).any())
print("There are missing values for EDSS in the y target space:", pd.isna(y_train['EDSS_6']).any())
# Out:
# There are missing values for EDSS in the X feature space: False
# There are missing values for EDSS in the y target space: False

# %%
for r in range(2, 37):
    
    X_train, X_test, y_train, y_test, all_train_pred, all_test_pred, mask_train, mask_test = generate_initial_predictions(r, X_train, X_test,y_train, y_test)
    
    mask_list.append((mask_train, mask_test))

    if (all_train_pred.shape[1] > 1):
        
        # update all previous predictions
        for col in range(1,all_train_pred.shape[1]):
            # for each column of the training and testing EDSS
            m_pred_train, m_pred_test = update_previous_predictions(col, all_train_pred, all_test_pred)    
            X_train, X_test = impute_previous_predictions(col, X_train, X_test, m_pred_train, m_pred_test, mask_list)
# Out:
# TRAIN
# NaN
# X reshaped is (33, 2, 115)
# y reshaped is (33, 2, 1)
# (33, 2, 115) (33, 2, 1)
# Full
# X reshaped is (360, 2, 115)
# y reshaped is (360, 2, 1)
# (360, 2, 115) (360, 2, 1)
# TEST
# NaN
# X reshaped is (22, 2, 115)
# y reshaped is (22, 2, 1)
# (22, 2, 115) (22, 2, 1)
# Full
# X reshaped is (76, 2, 115)
# y reshaped is (76, 2, 1)
# (76, 2, 115) (76, 2, 1)
# Train on 288 samples, validate on 72 samples
# Epoch 1/1
# 288/288 [==============================] - 2s 6ms/step - loss: 1.3893 - val_loss: 1.0831
# X reshaped is (393, 2, 115)
# y reshaped is (98, 2, 1)
# (393, 2, 115) (98, 2, 1)
# X reshaped is (98, 2, 115)
# y reshaped is (98, 2, 1)
# (98, 2, 115) (98, 2, 1)
# TRAIN
# NaN
# X reshaped is (56, 3, 115)
# y reshaped is (56, 3, 1)
# (56, 3, 115) (56, 3, 1)
# Full
# X reshaped is (337, 3, 115)
# y reshaped is (337, 3, 1)
# (337, 3, 115) (337, 3, 1)
# TEST
# NaN
# X reshaped is (33, 3, 115)
# y reshaped is (33, 3, 1)
# (33, 3, 115) (33, 3, 1)
# Full
# X reshaped is (65, 3, 115)
# y reshaped is (65, 3, 1)
# (65, 3, 115) (65, 3, 1)
# Train on 269 samples, validate on 68 samples
# Epoch 1/1
# 269/269 [==============================] - 2s 6ms/step - loss: 1.1218 - val_loss: 0.9069
# X reshaped is (393, 3, 115)
# y reshaped is (98, 3, 1)
# (393, 3, 115) (98, 3, 1)
# X reshaped is (98, 3, 115)
# y reshaped is (98, 3, 1)
# (98, 3, 115) (98, 3, 1)
# TRAIN
# NaN
# X reshaped is (41, 4, 115)
# y reshaped is (41, 4, 1)
# (41, 4, 115) (41, 4, 1)
# Full
# X reshaped is (352, 4, 115)
# y reshaped is (352, 4, 1)
# (352, 4, 115) (352, 4, 1)
# TEST
# NaN
# X reshaped is (41, 4, 115)
# y reshaped is (41, 4, 1)
# (41, 4, 115) (41, 4, 1)
# Full
# X reshaped is (57, 4, 115)
# y reshaped is (57, 4, 1)
# (57, 4, 115) (57, 4, 1)
# Train on 281 samples, validate on 71 samples
# Epoch 1/1
# 281/281 [==============================] - 2s 5ms/step - loss: 0.9955 - val_loss: 1.2941
# X reshaped is (393, 4, 115)
# y reshaped is (98, 4, 1)
# (393, 4, 115) (98, 4, 1)
# X reshaped is (98, 4, 115)
# y reshaped is (98, 4, 1)
# (98, 4, 115) (98, 4, 1)
# TRAIN
# NaN
# X reshaped is (80, 5, 115)
# y reshaped is (80, 5, 1)
# (80, 5, 115) (80, 5, 1)
# Full
# X reshaped is (313, 5, 115)
# y reshaped is (313, 5, 1)
# (313, 5, 115) (313, 5, 1)
# TEST
# NaN
# X reshaped is (47, 5, 115)
# y reshaped is (47, 5, 1)
# (47, 5, 115) (47, 5, 1)
# Full
# X reshaped is (51, 5, 115)
# y reshaped is (51, 5, 1)
# (51, 5, 115) (51, 5, 1)
# Train on 250 samples, validate on 63 samples
# Epoch 1/1
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1171 - val_loss: 0.8913
# X reshaped is (393, 5, 115)
# y reshaped is (98, 5, 1)
# (393, 5, 115) (98, 5, 1)
# X reshaped is (98, 5, 115)
# y reshaped is (98, 5, 1)
# (98, 5, 115) (98, 5, 1)
# TRAIN
# NaN
# X reshaped is (56, 6, 115)
# y reshaped is (56, 6, 1)
# (56, 6, 115) (56, 6, 1)
# Full
# X reshaped is (337, 6, 115)
# y reshaped is (337, 6, 1)
# (337, 6, 115) (337, 6, 1)
# TEST
# NaN
# X reshaped is (49, 6, 115)
# y reshaped is (49, 6, 1)
# (49, 6, 115) (49, 6, 1)
# Full
# X reshaped is (49, 6, 115)
# y reshaped is (49, 6, 1)
# (49, 6, 115) (49, 6, 1)
# Train on 269 samples, validate on 68 samples
# Epoch 1/1
# 269/269 [==============================] - 2s 6ms/step - loss: 0.9347 - val_loss: 1.1154
# X reshaped is (393, 6, 115)
# y reshaped is (98, 6, 1)
# (393, 6, 115) (98, 6, 1)
# X reshaped is (98, 6, 115)
# y reshaped is (98, 6, 1)
# (98, 6, 115) (98, 6, 1)
# TRAIN
# NaN
# X reshaped is (84, 7, 115)
# y reshaped is (84, 7, 1)
# (84, 7, 115) (84, 7, 1)
# Full
# X reshaped is (309, 7, 115)
# y reshaped is (309, 7, 1)
# (309, 7, 115) (309, 7, 1)
# TEST
# NaN
# X reshaped is (52, 7, 115)
# y reshaped is (52, 7, 1)
# (52, 7, 115) (52, 7, 1)
# Full
# X reshaped is (46, 7, 115)
# y reshaped is (46, 7, 1)
# (46, 7, 115) (46, 7, 1)
# Train on 247 samples, validate on 62 samples
# Epoch 1/1
# 247/247 [==============================] - 2s 7ms/step - loss: 0.9438 - val_loss: 1.0276
# X reshaped is (393, 7, 115)
# y reshaped is (98, 7, 1)
# (393, 7, 115) (98, 7, 1)
# X reshaped is (98, 7, 115)
# y reshaped is (98, 7, 1)
# (98, 7, 115) (98, 7, 1)
# TRAIN
# NaN
# X reshaped is (77, 8, 115)
# y reshaped is (77, 8, 1)
# (77, 8, 115) (77, 8, 1)
# Full
# X reshaped is (316, 8, 115)
# y reshaped is (316, 8, 1)
# (316, 8, 115) (316, 8, 1)
# TEST
# NaN
# X reshaped is (55, 8, 115)
# y reshaped is (55, 8, 1)
# (55, 8, 115) (55, 8, 1)
# Full
# X reshaped is (43, 8, 115)
# y reshaped is (43, 8, 1)
# (43, 8, 115) (43, 8, 1)
# Train on 252 samples, validate on 64 samples
# Epoch 1/1
# 252/252 [==============================] - 2s 7ms/step - loss: 1.0150 - val_loss: 1.0511
# X reshaped is (393, 8, 115)
# y reshaped is (98, 8, 1)
# (393, 8, 115) (98, 8, 1)
# X reshaped is (98, 8, 115)
# y reshaped is (98, 8, 1)
# (98, 8, 115) (98, 8, 1)
# TRAIN
# NaN
# X reshaped is (91, 9, 115)
# y reshaped is (91, 9, 1)
# (91, 9, 115) (91, 9, 1)
# Full
# X reshaped is (302, 9, 115)
# y reshaped is (302, 9, 1)
# (302, 9, 115) (302, 9, 1)
# TEST
# NaN
# X reshaped is (60, 9, 115)
# y reshaped is (60, 9, 1)
# (60, 9, 115) (60, 9, 1)
# Full
# X reshaped is (38, 9, 115)
# y reshaped is (38, 9, 1)
# (38, 9, 115) (38, 9, 1)
# Train on 241 samples, validate on 61 samples
# Epoch 1/1
# 241/241 [==============================] - 2s 7ms/step - loss: 0.9195 - val_loss: 0.9324
# X reshaped is (393, 9, 115)
# y reshaped is (98, 9, 1)
# (393, 9, 115) (98, 9, 1)
# X reshaped is (98, 9, 115)
# y reshaped is (98, 9, 1)
# (98, 9, 115) (98, 9, 1)
# TRAIN
# NaN
# X reshaped is (96, 10, 115)
# y reshaped is (96, 10, 1)
# (96, 10, 115) (96, 10, 1)
# Full
# X reshaped is (297, 10, 115)
# y reshaped is (297, 10, 1)
# (297, 10, 115) (297, 10, 1)
# TEST
# NaN
# X reshaped is (64, 10, 115)
# y reshaped is (64, 10, 1)
# (64, 10, 115) (64, 10, 1)
# Full
# X reshaped is (34, 10, 115)
# y reshaped is (34, 10, 1)
# (34, 10, 115) (34, 10, 1)
# Train on 237 samples, validate on 60 samples
# Epoch 1/1
# 237/237 [==============================] - 2s 7ms/step - loss: 0.9705 - val_loss: 1.0119
# X reshaped is (393, 10, 115)
# y reshaped is (98, 10, 1)
# (393, 10, 115) (98, 10, 1)
# X reshaped is (98, 10, 115)
# y reshaped is (98, 10, 1)
# (98, 10, 115) (98, 10, 1)
# TRAIN
# NaN
# X reshaped is (101, 11, 115)
# y reshaped is (101, 11, 1)
# (101, 11, 115) (101, 11, 1)
# Full
# X reshaped is (292, 11, 115)
# y reshaped is (292, 11, 1)
# (292, 11, 115) (292, 11, 1)
# TEST
# NaN
# X reshaped is (69, 11, 115)
# y reshaped is (69, 11, 1)
# (69, 11, 115) (69, 11, 1)
# Full
# X reshaped is (29, 11, 115)
# y reshaped is (29, 11, 1)
# (29, 11, 115) (29, 11, 1)
# Train on 233 samples, validate on 59 samples
# Epoch 1/1
# 233/233 [==============================] - 2s 7ms/step - loss: 0.9256 - val_loss: 0.7687
# X reshaped is (393, 11, 115)
# y reshaped is (98, 11, 1)
# (393, 11, 115) (98, 11, 1)
# X reshaped is (98, 11, 115)
# y reshaped is (98, 11, 1)
# (98, 11, 115) (98, 11, 1)
# TRAIN
# NaN
# X reshaped is (108, 12, 115)
# y reshaped is (108, 12, 1)
# (108, 12, 115) (108, 12, 1)
# Full
# X reshaped is (285, 12, 115)
# y reshaped is (285, 12, 1)
# (285, 12, 115) (285, 12, 1)
# TEST
# NaN
# X reshaped is (71, 12, 115)
# y reshaped is (71, 12, 1)
# (71, 12, 115) (71, 12, 1)
# Full
# X reshaped is (27, 12, 115)
# y reshaped is (27, 12, 1)
# (27, 12, 115) (27, 12, 1)
# Train on 228 samples, validate on 57 samples
# Epoch 1/1
# 228/228 [==============================] - 2s 8ms/step - loss: 0.7727 - val_loss: 1.2413
# X reshaped is (393, 12, 115)
# y reshaped is (98, 12, 1)
# (393, 12, 115) (98, 12, 1)
# X reshaped is (98, 12, 115)
# y reshaped is (98, 12, 1)
# (98, 12, 115) (98, 12, 1)
# TRAIN
# NaN
# X reshaped is (123, 13, 115)
# y reshaped is (123, 13, 1)
# (123, 13, 115) (123, 13, 1)
# Full
# X reshaped is (270, 13, 115)
# y reshaped is (270, 13, 1)
# (270, 13, 115) (270, 13, 1)
# TEST
# NaN
# X reshaped is (74, 13, 115)
# y reshaped is (74, 13, 1)
# (74, 13, 115) (74, 13, 1)
# Full
# X reshaped is (24, 13, 115)
# y reshaped is (24, 13, 1)
# (24, 13, 115) (24, 13, 1)
# Train on 216 samples, validate on 54 samples
# Epoch 1/1
# 216/216 [==============================] - 2s 9ms/step - loss: 1.1901 - val_loss: 0.8179
# X reshaped is (393, 13, 115)
# y reshaped is (98, 13, 1)
# (393, 13, 115) (98, 13, 1)
# X reshaped is (98, 13, 115)
# y reshaped is (98, 13, 1)
# (98, 13, 115) (98, 13, 1)
# TRAIN
# NaN
# X reshaped is (118, 14, 115)
# y reshaped is (118, 14, 1)
# (118, 14, 115) (118, 14, 1)
# Full
# X reshaped is (275, 14, 115)
# y reshaped is (275, 14, 1)
# (275, 14, 115) (275, 14, 1)
# TEST
# NaN
# X reshaped is (78, 14, 115)
# y reshaped is (78, 14, 1)
# (78, 14, 115) (78, 14, 1)
# Full
# X reshaped is (20, 14, 115)
# y reshaped is (20, 14, 1)
# (20, 14, 115) (20, 14, 1)
# Train on 220 samples, validate on 55 samples
# Epoch 1/1
# 220/220 [==============================] - 2s 7ms/step - loss: 0.7716 - val_loss: 0.9427
# X reshaped is (393, 14, 115)
# y reshaped is (98, 14, 1)
# (393, 14, 115) (98, 14, 1)
# X reshaped is (98, 14, 115)
# y reshaped is (98, 14, 1)
# (98, 14, 115) (98, 14, 1)
# TRAIN
# NaN
# X reshaped is (147, 15, 115)
# y reshaped is (147, 15, 1)
# (147, 15, 115) (147, 15, 1)
# Full
# X reshaped is (246, 15, 115)
# y reshaped is (246, 15, 1)
# (246, 15, 115) (246, 15, 1)
# TEST
# NaN
# X reshaped is (82, 15, 115)
# y reshaped is (82, 15, 1)
# (82, 15, 115) (82, 15, 1)
# Full
# X reshaped is (16, 15, 115)
# y reshaped is (16, 15, 1)
# (16, 15, 115) (16, 15, 1)
# Train on 196 samples, validate on 50 samples
# Epoch 1/1
# 196/196 [==============================] - 2s 10ms/step - loss: 0.9044 - val_loss: 0.9194
# X reshaped is (393, 15, 115)
# y reshaped is (98, 15, 1)
# (393, 15, 115) (98, 15, 1)
# X reshaped is (98, 15, 115)
# y reshaped is (98, 15, 1)
# (98, 15, 115) (98, 15, 1)
# TRAIN
# NaN
# X reshaped is (137, 16, 115)
# y reshaped is (137, 16, 1)
# (137, 16, 115) (137, 16, 1)
# Full
# X reshaped is (256, 16, 115)
# y reshaped is (256, 16, 1)
# (256, 16, 115) (256, 16, 1)
# TEST
# NaN
# X reshaped is (83, 16, 115)
# y reshaped is (83, 16, 1)
# (83, 16, 115) (83, 16, 1)
# Full
# X reshaped is (15, 16, 115)
# y reshaped is (15, 16, 1)
# (15, 16, 115) (15, 16, 1)
# Train on 204 samples, validate on 52 samples
# Epoch 1/1
# 204/204 [==============================] - 2s 9ms/step - loss: 0.9385 - val_loss: 0.8204
# X reshaped is (393, 16, 115)
# y reshaped is (98, 16, 1)
# (393, 16, 115) (98, 16, 1)
# X reshaped is (98, 16, 115)
# y reshaped is (98, 16, 1)
# (98, 16, 115) (98, 16, 1)
# TRAIN
# NaN
# X reshaped is (175, 17, 115)
# y reshaped is (175, 17, 1)
# (175, 17, 115) (175, 17, 1)
# Full
# X reshaped is (218, 17, 115)
# y reshaped is (218, 17, 1)
# (218, 17, 115) (218, 17, 1)
# TEST
# NaN
# X reshaped is (84, 17, 115)
# y reshaped is (84, 17, 1)
# (84, 17, 115) (84, 17, 1)
# Full
# X reshaped is (14, 17, 115)
# y reshaped is (14, 17, 1)
# (14, 17, 115) (14, 17, 1)
# Train on 174 samples, validate on 44 samples
# Epoch 1/1
# 174/174 [==============================] - 2s 14ms/step - loss: 0.7354 - val_loss: 1.0800
# X reshaped is (393, 17, 115)
# y reshaped is (98, 17, 1)
# (393, 17, 115) (98, 17, 1)
# X reshaped is (98, 17, 115)
# y reshaped is (98, 17, 1)
# (98, 17, 115) (98, 17, 1)
# TRAIN
# NaN
# X reshaped is (163, 18, 115)
# y reshaped is (163, 18, 1)
# (163, 18, 115) (163, 18, 1)
# Full
# X reshaped is (230, 18, 115)
# y reshaped is (230, 18, 1)
# (230, 18, 115) (230, 18, 1)
# TEST
# NaN
# X reshaped is (85, 18, 115)
# y reshaped is (85, 18, 1)
# (85, 18, 115) (85, 18, 1)
# Full
# X reshaped is (13, 18, 115)
# y reshaped is (13, 18, 1)
# (13, 18, 115) (13, 18, 1)
# Train on 184 samples, validate on 46 samples
# Epoch 1/1
# 184/184 [==============================] - 2s 13ms/step - loss: 1.0509 - val_loss: 0.8360
# X reshaped is (393, 18, 115)
# y reshaped is (98, 18, 1)
# (393, 18, 115) (98, 18, 1)
# X reshaped is (98, 18, 115)
# y reshaped is (98, 18, 1)
# (98, 18, 115) (98, 18, 1)
# TRAIN
# NaN
# X reshaped is (189, 19, 115)
# y reshaped is (189, 19, 1)
# (189, 19, 115) (189, 19, 1)
# Full
# X reshaped is (204, 19, 115)
# y reshaped is (204, 19, 1)
# (204, 19, 115) (204, 19, 1)
# TEST
# NaN
# X reshaped is (87, 19, 115)
# y reshaped is (87, 19, 1)
# (87, 19, 115) (87, 19, 1)
# Full
# X reshaped is (11, 19, 115)
# y reshaped is (11, 19, 1)
# (11, 19, 115) (11, 19, 1)
# Train on 163 samples, validate on 41 samples
# Epoch 1/1
# 163/163 [==============================] - 2s 12ms/step - loss: 0.7608 - val_loss: 1.0447
# X reshaped is (393, 19, 115)
# y reshaped is (98, 19, 1)
# (393, 19, 115) (98, 19, 1)
# X reshaped is (98, 19, 115)
# y reshaped is (98, 19, 1)
# (98, 19, 115) (98, 19, 1)
# TRAIN
# NaN
# X reshaped is (200, 20, 115)
# y reshaped is (200, 20, 1)
# (200, 20, 115) (200, 20, 1)
# Full
# X reshaped is (193, 20, 115)
# y reshaped is (193, 20, 1)
# (193, 20, 115) (193, 20, 1)
# TEST
# NaN
# X reshaped is (88, 20, 115)
# y reshaped is (88, 20, 1)
# (88, 20, 115) (88, 20, 1)
# Full
# X reshaped is (10, 20, 115)
# y reshaped is (10, 20, 1)
# (10, 20, 115) (10, 20, 1)
# Train on 154 samples, validate on 39 samples
# Epoch 1/1
# 154/154 [==============================] - 2s 12ms/step - loss: 1.0354 - val_loss: 0.8069
# X reshaped is (393, 20, 115)
# y reshaped is (98, 20, 1)
# (393, 20, 115) (98, 20, 1)
# X reshaped is (98, 20, 115)
# y reshaped is (98, 20, 1)
# (98, 20, 115) (98, 20, 1)
# TRAIN
# NaN
# X reshaped is (219, 21, 115)
# y reshaped is (219, 21, 1)
# (219, 21, 115) (219, 21, 1)
# Full
# X reshaped is (174, 21, 115)
# y reshaped is (174, 21, 1)
# (174, 21, 115) (174, 21, 1)
# TEST
# NaN
# X reshaped is (88, 21, 115)
# y reshaped is (88, 21, 1)
# (88, 21, 115) (88, 21, 1)
# Full
# X reshaped is (10, 21, 115)
# y reshaped is (10, 21, 1)
# (10, 21, 115) (10, 21, 1)
# Train on 139 samples, validate on 35 samples
# Epoch 1/1
# 139/139 [==============================] - 2s 13ms/step - loss: 0.7466 - val_loss: 0.8339
# X reshaped is (393, 21, 115)
# y reshaped is (98, 21, 1)
# (393, 21, 115) (98, 21, 1)
# X reshaped is (98, 21, 115)
# y reshaped is (98, 21, 1)
# (98, 21, 115) (98, 21, 1)
# TRAIN
# NaN
# X reshaped is (217, 22, 115)
# y reshaped is (217, 22, 1)
# (217, 22, 115) (217, 22, 1)
# Full
# X reshaped is (176, 22, 115)
# y reshaped is (176, 22, 1)
# (176, 22, 115) (176, 22, 1)
# TEST
# NaN
# X reshaped is (89, 22, 115)
# y reshaped is (89, 22, 1)
# (89, 22, 115) (89, 22, 1)
# Full
# X reshaped is (9, 22, 115)
# y reshaped is (9, 22, 1)
# (9, 22, 115) (9, 22, 1)
# Train on 140 samples, validate on 36 samples
# Epoch 1/1
# 140/140 [==============================] - 2s 14ms/step - loss: 0.8242 - val_loss: 0.9702
# X reshaped is (393, 22, 115)
# y reshaped is (98, 22, 1)
# (393, 22, 115) (98, 22, 1)
# X reshaped is (98, 22, 115)
# y reshaped is (98, 22, 1)
# (98, 22, 115) (98, 22, 1)
# TRAIN
# NaN
# X reshaped is (249, 23, 115)
# y reshaped is (249, 23, 1)
# (249, 23, 115) (249, 23, 1)
# Full
# X reshaped is (144, 23, 115)
# y reshaped is (144, 23, 1)
# (144, 23, 115) (144, 23, 1)
# TEST
# NaN
# X reshaped is (89, 23, 115)
# y reshaped is (89, 23, 1)
# (89, 23, 115) (89, 23, 1)
# Full
# X reshaped is (9, 23, 115)
# y reshaped is (9, 23, 1)
# (9, 23, 115) (9, 23, 1)
# Train on 115 samples, validate on 29 samples
# Epoch 1/1
# 115/115 [==============================] - 2s 17ms/step - loss: 0.9866 - val_loss: 0.6496
# X reshaped is (393, 23, 115)
# y reshaped is (98, 23, 1)
# (393, 23, 115) (98, 23, 1)
# X reshaped is (98, 23, 115)
# y reshaped is (98, 23, 1)
# (98, 23, 115) (98, 23, 1)
# TRAIN
# NaN
# X reshaped is (259, 24, 115)
# y reshaped is (259, 24, 1)
# (259, 24, 115) (259, 24, 1)
# Full
# X reshaped is (134, 24, 115)
# y reshaped is (134, 24, 1)
# (134, 24, 115) (134, 24, 1)
# TEST
# NaN
# X reshaped is (90, 24, 115)
# y reshaped is (90, 24, 1)
# (90, 24, 115) (90, 24, 1)
# Full
# X reshaped is (8, 24, 115)
# y reshaped is (8, 24, 1)
# (8, 24, 115) (8, 24, 1)
# Train on 107 samples, validate on 27 samples
# Epoch 1/1
# 107/107 [==============================] - 2s 17ms/step - loss: 0.7053 - val_loss: 1.2615
# X reshaped is (393, 24, 115)
# y reshaped is (98, 24, 1)
# (393, 24, 115) (98, 24, 1)
# X reshaped is (98, 24, 115)
# y reshaped is (98, 24, 1)
# (98, 24, 115) (98, 24, 1)
# TRAIN
# NaN
# X reshaped is (288, 25, 115)
# y reshaped is (288, 25, 1)
# (288, 25, 115) (288, 25, 1)
# Full
# X reshaped is (105, 25, 115)
# y reshaped is (105, 25, 1)
# (105, 25, 115) (105, 25, 1)
# TEST
# NaN
# X reshaped is (93, 25, 115)
# y reshaped is (93, 25, 1)
# (93, 25, 115) (93, 25, 1)
# Full
# X reshaped is (5, 25, 115)
# y reshaped is (5, 25, 1)
# (5, 25, 115) (5, 25, 1)
# Train on 84 samples, validate on 21 samples
# Epoch 1/1
# 84/84 [==============================] - 2s 23ms/step - loss: 1.2870 - val_loss: 0.6620
# X reshaped is (393, 25, 115)
# y reshaped is (98, 25, 1)
# (393, 25, 115) (98, 25, 1)
# X reshaped is (98, 25, 115)
# y reshaped is (98, 25, 1)
# (98, 25, 115) (98, 25, 1)
# TRAIN
# NaN
# X reshaped is (299, 26, 115)
# y reshaped is (299, 26, 1)
# (299, 26, 115) (299, 26, 1)
# Full
# X reshaped is (94, 26, 115)
# y reshaped is (94, 26, 1)
# (94, 26, 115) (94, 26, 1)
# TEST
# NaN
# X reshaped is (94, 26, 115)
# y reshaped is (94, 26, 1)
# (94, 26, 115) (94, 26, 1)
# Full
# X reshaped is (4, 26, 115)
# y reshaped is (4, 26, 1)
# (4, 26, 115) (4, 26, 1)
# Train on 75 samples, validate on 19 samples
# Epoch 1/1
# 75/75 [==============================] - 2s 30ms/step - loss: 0.6608 - val_loss: 1.1551
# X reshaped is (393, 26, 115)
# y reshaped is (98, 26, 1)
# (393, 26, 115) (98, 26, 1)
# X reshaped is (98, 26, 115)
# y reshaped is (98, 26, 1)
# (98, 26, 115) (98, 26, 1)
# TRAIN
# NaN
# X reshaped is (299, 27, 115)
# y reshaped is (299, 27, 1)
# (299, 27, 115) (299, 27, 1)
# Full
# X reshaped is (94, 27, 115)
# y reshaped is (94, 27, 1)
# (94, 27, 115) (94, 27, 1)
# TEST
# NaN
# X reshaped is (95, 27, 115)
# y reshaped is (95, 27, 1)
# (95, 27, 115) (95, 27, 1)
# Full
# X reshaped is (3, 27, 115)
# y reshaped is (3, 27, 1)
# (3, 27, 115) (3, 27, 1)
# Train on 75 samples, validate on 19 samples
# Epoch 1/1
# 75/75 [==============================] - 2s 22ms/step - loss: 1.2164 - val_loss: 0.6916
# X reshaped is (393, 27, 115)
# y reshaped is (98, 27, 1)
# (393, 27, 115) (98, 27, 1)
# X reshaped is (98, 27, 115)
# y reshaped is (98, 27, 1)
# (98, 27, 115) (98, 27, 1)
# TRAIN
# NaN
# X reshaped is (324, 28, 115)
# y reshaped is (324, 28, 1)
# (324, 28, 115) (324, 28, 1)
# Full
# X reshaped is (69, 28, 115)
# y reshaped is (69, 28, 1)
# (69, 28, 115) (69, 28, 1)
# TEST
# NaN
# X reshaped is (95, 28, 115)
# y reshaped is (95, 28, 1)
# (95, 28, 115) (95, 28, 1)
# Full
# X reshaped is (3, 28, 115)
# y reshaped is (3, 28, 1)
# (3, 28, 115) (3, 28, 1)
# Train on 55 samples, validate on 14 samples
# Epoch 1/1
# 55/55 [==============================] - 2s 34ms/step - loss: 0.6324 - val_loss: 1.1221
# X reshaped is (393, 28, 115)
# y reshaped is (98, 28, 1)
# (393, 28, 115) (98, 28, 1)
# X reshaped is (98, 28, 115)
# y reshaped is (98, 28, 1)
# (98, 28, 115) (98, 28, 1)
# TRAIN
# NaN
# X reshaped is (334, 29, 115)
# y reshaped is (334, 29, 1)
# (334, 29, 115) (334, 29, 1)
# Full
# X reshaped is (59, 29, 115)
# y reshaped is (59, 29, 1)
# (59, 29, 115) (59, 29, 1)
# TEST
# NaN
# X reshaped is (96, 29, 115)
# y reshaped is (96, 29, 1)
# (96, 29, 115) (96, 29, 1)
# Full
# X reshaped is (2, 29, 115)
# y reshaped is (2, 29, 1)
# (2, 29, 115) (2, 29, 1)
# Train on 47 samples, validate on 12 samples
# Epoch 1/1
# 47/47 [==============================] - 2s 44ms/step - loss: 1.0895 - val_loss: 0.7175
# X reshaped is (393, 29, 115)
# y reshaped is (98, 29, 1)
# (393, 29, 115) (98, 29, 1)
# X reshaped is (98, 29, 115)
# y reshaped is (98, 29, 1)
# (98, 29, 115) (98, 29, 1)
# TRAIN
# NaN
# X reshaped is (349, 30, 115)
# y reshaped is (349, 30, 1)
# (349, 30, 115) (349, 30, 1)
# Full
# X reshaped is (44, 30, 115)
# y reshaped is (44, 30, 1)
# (44, 30, 115) (44, 30, 1)
# TEST
# NaN
# X reshaped is (97, 30, 115)
# y reshaped is (97, 30, 1)
# (97, 30, 115) (97, 30, 1)
# Full
# X reshaped is (1, 30, 115)
# y reshaped is (1, 30, 1)
# (1, 30, 115) (1, 30, 1)
# Train on 35 samples, validate on 9 samples
# Epoch 1/1
# 35/35 [==============================] - 2s 66ms/step - loss: 0.6482 - val_loss: 1.1658
# X reshaped is (393, 30, 115)
# y reshaped is (98, 30, 1)
# (393, 30, 115) (98, 30, 1)
# X reshaped is (98, 30, 115)
# y reshaped is (98, 30, 1)
# (98, 30, 115) (98, 30, 1)
# TRAIN
# NaN
# X reshaped is (358, 31, 115)
# y reshaped is (358, 31, 1)
# (358, 31, 115) (358, 31, 1)
# Full
# X reshaped is (35, 31, 115)
# y reshaped is (35, 31, 1)
# (35, 31, 115) (35, 31, 1)
# TEST
# NaN
# X reshaped is (97, 31, 115)
# y reshaped is (97, 31, 1)
# (97, 31, 115) (97, 31, 1)
# Full
# X reshaped is (1, 31, 115)
# y reshaped is (1, 31, 1)
# (1, 31, 115) (1, 31, 1)
# Train on 28 samples, validate on 7 samples
# Epoch 1/1
# 28/28 [==============================] - 2s 71ms/step - loss: 0.9733 - val_loss: 0.7568
# X reshaped is (393, 31, 115)
# y reshaped is (98, 31, 1)
# (393, 31, 115) (98, 31, 1)
# X reshaped is (98, 31, 115)
# y reshaped is (98, 31, 1)
# (98, 31, 115) (98, 31, 1)
# TRAIN
# NaN
# X reshaped is (357, 32, 115)
# y reshaped is (357, 32, 1)
# (357, 32, 115) (357, 32, 1)
# Full
# X reshaped is (36, 32, 115)
# y reshaped is (36, 32, 1)
# (36, 32, 115) (36, 32, 1)
# TEST
# NaN
# X reshaped is (98, 32, 115)
# y reshaped is (98, 32, 1)
# (98, 32, 115) (98, 32, 1)
# Full
# X reshaped is (0, 32, 115)
# y reshaped is (0, 32, 1)
# (0, 32, 115) (0, 32, 1)
# Train on 28 samples, validate on 8 samples
# Epoch 1/1
# 28/28 [==============================] - 2s 72ms/step - loss: 0.5764 - val_loss: 0.8970
# X reshaped is (393, 32, 115)
# y reshaped is (98, 32, 1)
# (393, 32, 115) (98, 32, 1)
# X reshaped is (98, 32, 115)
# y reshaped is (98, 32, 1)
# (98, 32, 115) (98, 32, 1)
# TRAIN
# NaN
# X reshaped is (370, 33, 115)
# y reshaped is (370, 33, 1)
# (370, 33, 115) (370, 33, 1)
# Full
# X reshaped is (23, 33, 115)
# y reshaped is (23, 33, 1)
# (23, 33, 115) (23, 33, 1)
# TEST
# NaN
# X reshaped is (98, 33, 115)
# y reshaped is (98, 33, 1)
# (98, 33, 115) (98, 33, 1)
# Full
# X reshaped is (0, 33, 115)
# y reshaped is (0, 33, 1)
# (0, 33, 115) (0, 33, 1)
# Train on 18 samples, validate on 5 samples
# Epoch 1/1
# 18/18 [==============================] - 2s 119ms/step - loss: 0.7941 - val_loss: 0.9250
# X reshaped is (393, 33, 115)
# y reshaped is (98, 33, 1)
# (393, 33, 115) (98, 33, 1)
# X reshaped is (98, 33, 115)
# y reshaped is (98, 33, 1)
# (98, 33, 115) (98, 33, 1)
# TRAIN
# NaN
# X reshaped is (382, 34, 115)
# y reshaped is (382, 34, 1)
# (382, 34, 115) (382, 34, 1)
# Full
# X reshaped is (11, 34, 115)
# y reshaped is (11, 34, 1)
# (11, 34, 115) (11, 34, 1)
# TEST
# NaN
# X reshaped is (98, 34, 115)
# y reshaped is (98, 34, 1)
# (98, 34, 115) (98, 34, 1)
# Full
# X reshaped is (0, 34, 115)
# y reshaped is (0, 34, 1)
# (0, 34, 115) (0, 34, 1)
# Train on 8 samples, validate on 3 samples
# Epoch 1/1
# 8/8 [==============================] - 2s 204ms/step - loss: 0.8783 - val_loss: 0.8635
# X reshaped is (393, 34, 115)
# y reshaped is (98, 34, 1)
# (393, 34, 115) (98, 34, 1)
# X reshaped is (98, 34, 115)
# y reshaped is (98, 34, 1)
# (98, 34, 115) (98, 34, 1)
# TRAIN
# NaN
# X reshaped is (389, 35, 115)
# y reshaped is (389, 35, 1)
# (389, 35, 115) (389, 35, 1)
# Full
# X reshaped is (4, 35, 115)
# y reshaped is (4, 35, 1)
# (4, 35, 115) (4, 35, 1)
# TEST
# NaN
# X reshaped is (98, 35, 115)
# y reshaped is (98, 35, 1)
# (98, 35, 115) (98, 35, 1)
# Full
# X reshaped is (0, 35, 115)
# y reshaped is (0, 35, 1)
# (0, 35, 115) (0, 35, 1)
# Train on 3 samples, validate on 1 samples
# Epoch 1/1
# 3/3 [==============================] - 2s 815ms/step - loss: 0.7530 - val_loss: 0.3602
# X reshaped is (393, 35, 115)
# y reshaped is (98, 35, 1)
# (393, 35, 115) (98, 35, 1)
# X reshaped is (98, 35, 115)
# y reshaped is (98, 35, 1)
# (98, 35, 115) (98, 35, 1)
# TRAIN
# NaN
# X reshaped is (387, 36, 115)
# y reshaped is (387, 36, 1)
# (387, 36, 115) (387, 36, 1)
# Full
# X reshaped is (6, 36, 115)
# y reshaped is (6, 36, 1)
# (6, 36, 115) (6, 36, 1)
# TEST
# NaN
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Full
# X reshaped is (0, 36, 115)
# y reshaped is (0, 36, 1)
# (0, 36, 115) (0, 36, 1)
# Train on 4 samples, validate on 2 samples
# Epoch 1/1
# 4/4 [==============================] - 2s 583ms/step - loss: 0.7822 - val_loss: 0.8643
# X reshaped is (393, 36, 115)
# y reshaped is (98, 36, 1)
# (393, 36, 115) (98, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)

# %% [markdown]
# # X_train should go up to 210

# %%
save_temp = (X_train, X_test, y_train, y_test, all_train_pred, all_test_pred, mask_train, mask_test)
save_list_temp = mask_list.copy()

# %%
X_train, X_test, y_train, y_test, all_train_pred, all_test_pred, mask_train, mask_test = save_temp 
mask_list = save_list_temp

# %% [markdown]
# # Try

# %%
def final_model(X_train, y_train, X_test, y_test, n_inputs=115):
    
    """Running the model after we've impute for the whole feature space"""
    
    n_time_steps = len(y_train.columns)
    
    X_train_all, y_train_all = provide_all_data(X_train, y_train, n_time_steps)
    X_test_all, y_test_all = provide_all_data(X_test, y_test, n_time_steps)
    
    # we do want to mask the instances of the testing data where there are missing targets
    # so that it does not affect our val_loss
    masked_X_train_all, masked_y_train_all = prepare_for_mask(X_train_all, y_train_all)
    masked_X_test_all, masked_y_test_all = prepare_for_mask(X_test_all, y_test_all)
    
    K.clear_session()

    m = M.Sequential()
    m.add(L.Masking(mask_value=-99, input_shape=(n_time_steps, n_inputs)))
    m.add(L.GRU(128, return_sequences=True))
    m.add(L.Dense(1, activation='relu'))
    m.compile(optimizer = 'nadam', loss = 'mean_absolute_error')

    # load weights from previous model to establish continuity 
    m.load_weights(final_file_path)
    
    history = m.fit(masked_X_train_all, masked_y_train_all,
                    validation_split = 0.2, 
                    batch_size = X_train_all.shape[0], # of training instances == batch_size 
                    epochs=1,
                    shuffle=True,
                   callbacks = callbacks_list_final) # should save best weights 
    
    m.save_weights(final_file_path)
    
    all_train_pred = m.predict(X_train_all)
    all_test_pred = m.predict(masked_X_test_all)
    
    val_loss = history.__dict__['history']['val_loss']
    
    return all_train_pred, all_test_pred, val_loss, m

# %%
def run_model(r, X_train, y_train, X_test, y_test):
    """We need to divide our RNN into different 1 epoch models in order to iteratively update the imputations"""
    val_loss_list = []
    
    for i in range(r):
        
        all_train_pred, all_test_pred, val_loss, model = final_model(X_train, y_train, X_test, y_test)

        val_loss_list.append(val_loss)
    
        for i in range(1, all_train_pred.shape[1]): # -1 

                    m_pred_train, m_pred_test = update_previous_predictions(i, all_train_pred, all_test_pred)    
                    
                    X_train, X_test = impute_previous_predictions(i, X_train, X_test, m_pred_train, m_pred_test, mask_list)
    
    return np.min(val_loss_list), model

# %% [markdown]
# # Replace test and train y with original copies to mask missing target values

# %%
best, model = run_model(500, X_train, y_train_og, X_test, y_test_og) # use original y test
# Out:
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 3s 8ms/step - loss: 1.0313 - val_loss: 0.7479
#
# Epoch 00001: val_loss improved from inf to 0.74793, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7731 - val_loss: 1.0410
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 1.0105 - val_loss: 0.7632
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7719 - val_loss: 0.8274
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7542 - val_loss: 0.9225
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9967 - val_loss: 0.8244
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7463 - val_loss: 0.7625
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7615 - val_loss: 0.8260
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7439 - val_loss: 0.9199
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9898 - val_loss: 0.8199
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 0.7382 - val_loss: 0.9164
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 0.9830 - val_loss: 0.8205
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7349 - val_loss: 0.9101
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 0.9767 - val_loss: 0.8186
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7321 - val_loss: 0.9037
#
# Epoch 00001: val_loss did not improve from 0.74793
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 0.9670 - val_loss: 0.7141
#
# Epoch 00001: val_loss improved from 0.74793 to 0.71410, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6196 - val_loss: 0.8924
#
# Epoch 00001: val_loss did not improve from 0.71410
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8988 - val_loss: 0.8524
#
# Epoch 00001: val_loss did not improve from 0.71410
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8016 - val_loss: 0.8679
#
# Epoch 00001: val_loss did not improve from 0.71410
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8868 - val_loss: 0.7246
#
# Epoch 00001: val_loss did not improve from 0.71410
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6206 - val_loss: 1.0145
#
# Epoch 00001: val_loss did not improve from 0.71410
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0824 - val_loss: 0.7025
#
# Epoch 00001: val_loss improved from 0.71410 to 0.70251, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6050 - val_loss: 1.2106
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.2280 - val_loss: 0.7281
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6034 - val_loss: 0.8279
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8508 - val_loss: 0.7159
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6008 - val_loss: 1.0181
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0905 - val_loss: 0.7153
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5978 - val_loss: 0.8296
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8419 - val_loss: 0.7132
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5961 - val_loss: 0.8268
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8387 - val_loss: 0.7131
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5948 - val_loss: 1.0097
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0763 - val_loss: 0.7122
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5929 - val_loss: 1.0079
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 1.0729 - val_loss: 0.7117
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5907 - val_loss: 1.0031
#
# Epoch 00001: val_loss did not improve from 0.70251
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0660 - val_loss: 0.6881
#
# Epoch 00001: val_loss improved from 0.70251 to 0.68813, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5933 - val_loss: 0.9231
#
# Epoch 00001: val_loss did not improve from 0.68813
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8627 - val_loss: 0.7514
#
# Epoch 00001: val_loss did not improve from 0.68813
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7387 - val_loss: 0.7500
#
# Epoch 00001: val_loss did not improve from 0.68813
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6385 - val_loss: 0.9159
#
# Epoch 00001: val_loss did not improve from 0.68813
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9583 - val_loss: 0.6797
#
# Epoch 00001: val_loss improved from 0.68813 to 0.67967, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 7ms/step - loss: 0.5695 - val_loss: 0.9482
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8916 - val_loss: 0.7386
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7181 - val_loss: 0.9389
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8842 - val_loss: 0.7376
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7152 - val_loss: 0.7602
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6490 - val_loss: 0.7418
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7140 - val_loss: 0.9343
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8756 - val_loss: 0.7350
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7106 - val_loss: 0.9320
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8722 - val_loss: 0.7350
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7092 - val_loss: 0.9314
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8698 - val_loss: 0.7329
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7063 - val_loss: 0.7606
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6459 - val_loss: 0.7356
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7042 - val_loss: 0.7615
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6444 - val_loss: 0.8829
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9150 - val_loss: 0.6803
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5584 - val_loss: 0.6857
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5841 - val_loss: 0.9803
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8996 - val_loss: 0.7175
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6839 - val_loss: 0.9735
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8911 - val_loss: 0.7158
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6804 - val_loss: 0.9705
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8884 - val_loss: 0.7142
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6776 - val_loss: 0.9662
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8830 - val_loss: 0.7129
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6766 - val_loss: 0.9623
#
# Epoch 00001: val_loss did not improve from 0.67967
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8799 - val_loss: 0.6744
#
# Epoch 00001: val_loss improved from 0.67967 to 0.67437, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5598 - val_loss: 0.9360
#
# Epoch 00001: val_loss did not improve from 0.67437
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8454 - val_loss: 0.6643
#
# Epoch 00001: val_loss improved from 0.67437 to 0.66432, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5585 - val_loss: 1.1748
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.1382 - val_loss: 0.7194
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5680 - val_loss: 0.9525
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0180 - val_loss: 0.6776
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5487 - val_loss: 1.2092
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.1812 - val_loss: 0.6654
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5450 - val_loss: 1.2049
#
# Epoch 00001: val_loss did not improve from 0.66432
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.1708 - val_loss: 0.6624
#
# Epoch 00001: val_loss improved from 0.66432 to 0.66235, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5434 - val_loss: 1.1974
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.1615 - val_loss: 0.7242
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5660 - val_loss: 0.7797
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7757 - val_loss: 0.7126
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5622 - val_loss: 0.7827
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7730 - val_loss: 0.8467
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7394 - val_loss: 0.7731
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7674 - val_loss: 0.8455
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7381 - val_loss: 0.6740
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5863 - val_loss: 1.0598
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0016 - val_loss: 0.6848
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5316 - val_loss: 0.9648
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.0159 - val_loss: 0.7239
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5736 - val_loss: 0.7900
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7710 - val_loss: 0.7201
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5675 - val_loss: 0.9386
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9890 - val_loss: 0.6765
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5363 - val_loss: 1.1887
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 1.1538 - val_loss: 0.6660
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5339 - val_loss: 0.9339
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8416 - val_loss: 0.7197
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6810 - val_loss: 0.7565
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6132 - val_loss: 0.7247
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6804 - val_loss: 0.7561
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6115 - val_loss: 0.7242
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6790 - val_loss: 0.9221
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8321 - val_loss: 0.7188
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6758 - val_loss: 0.9191
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8266 - val_loss: 0.7189
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6745 - val_loss: 0.7529
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6076 - val_loss: 0.8625
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8826 - val_loss: 0.6744
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5162 - val_loss: 0.7363
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6211 - val_loss: 0.8653
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8840 - val_loss: 0.6688
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5152 - val_loss: 0.6938
#
# Epoch 00001: val_loss did not improve from 0.66235
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5614 - val_loss: 0.6598
#
# Epoch 00001: val_loss improved from 0.66235 to 0.65983, saving model to best/best_weights_6m|6m.hdf5
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5177 - val_loss: 0.9654
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.8347 - val_loss: 0.6933
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5685 - val_loss: 0.8543
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7104 - val_loss: 0.7691
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7648 - val_loss: 0.8369
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7021 - val_loss: 0.6741
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5818 - val_loss: 1.0455
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9568 - val_loss: 0.6714
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5789 - val_loss: 1.0404
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.9503 - val_loss: 0.6718
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5770 - val_loss: 0.8299
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6921 - val_loss: 0.7672
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.7558 - val_loss: 0.8238
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6898 - val_loss: 0.6745
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# ...
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4768 - val_loss: 0.7343
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3666 - val_loss: 0.7909
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4914 - val_loss: 0.7285
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4771 - val_loss: 0.8522
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5669 - val_loss: 0.7330
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4716 - val_loss: 0.8592
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5469 - val_loss: 0.7344
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4673 - val_loss: 0.8594
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5400 - val_loss: 0.7326
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4638 - val_loss: 0.7732
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3993 - val_loss: 0.7345
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4615 - val_loss: 0.8523
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5309 - val_loss: 0.7175
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3699 - val_loss: 0.9767
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6753 - val_loss: 0.7443
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3550 - val_loss: 0.7457
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4895 - val_loss: 0.8292
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4966 - val_loss: 0.7529
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4944 - val_loss: 0.8399
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4846 - val_loss: 0.7495
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4918 - val_loss: 0.7631
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3682 - val_loss: 0.7939
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6322 - val_loss: 0.7598
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3722 - val_loss: 0.7530
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4801 - val_loss: 0.8516
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4936 - val_loss: 0.7471
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4774 - val_loss: 0.7773
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3689 - val_loss: 0.7419
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4749 - val_loss: 0.8323
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4843 - val_loss: 0.7509
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4845 - val_loss: 0.7667
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3666 - val_loss: 0.8137
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.6060 - val_loss: 0.7925
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3785 - val_loss: 0.7433
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4645 - val_loss: 0.8312
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4888 - val_loss: 0.7459
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4695 - val_loss: 0.7664
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3734 - val_loss: 0.8093
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5949 - val_loss: 0.7949
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3767 - val_loss: 0.7875
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5866 - val_loss: 0.7711
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3781 - val_loss: 0.7473
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.4470 - val_loss: 0.7805
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.3774 - val_loss: 0.7907
#
# Epoch 00001: val_loss did not improve from 0.65983
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)
# Train on 314 samples, validate on 79 samples
# Epoch 1/1
# 314/314 [==============================] - 2s 6ms/step - loss: 0.5786 - val_loss: 0.7449
#
# Epoch 00001: val_loss did not improve from 0.65983

# %%
best
# Out:
# 0.6598294973373413

# %%
def best_model(X_train, y_train, X_test, y_test, n_inputs=115):
    
    """Running the model after we've impute for the whole feature space"""
    
    n_time_steps = len(y_train.columns)
    
    X_train_all, y_train_all = provide_all_data(X_train, y_train, n_time_steps)
    X_test_all, y_test_all = provide_all_data(X_test, y_test, n_time_steps)
    
    # we do want to mask the instances of the testing data where there are missing targets
    # so that it does not affect our val_loss
    masked_X_test_all, masked_y_test_all = prepare_for_mask(X_test_all, y_test_all)
    
    K.clear_session()
    m = M.Sequential()
    m.add(L.Masking(mask_value=-99, input_shape=(n_time_steps, n_inputs)))
    m.add(L.GRU(128, return_sequences=True))
    m.add(L.Dense(1, activation='relu'))
    m.compile(optimizer = 'nadam', loss = 'mean_absolute_error')

    # load weights from previous model to establish continuity 
    m.load_weights(best_file_path)
    
    all_train_pred = m.predict(X_train_all)
    all_test_pred = m.predict(masked_X_test_all)
    
    return all_train_pred, all_test_pred, m

# %%
def return_imputed_data(X_train, y_train, X_test, y_test):
    """Imputes for test data Feature EDSS with best model weights and then evaluates test data"""
    val_loss_list = []
    
    all_train_pred, all_test_pred, m = best_model(X_train, y_train, X_test, y_test)
    
    for i in range(1, all_train_pred.shape[1]): # -1 

                m_pred_train, m_pred_test = update_previous_predictions(i, all_train_pred, all_test_pred)    
                    
                X_train, X_test = impute_previous_predictions(i, X_train, X_test, m_pred_train, m_pred_test, mask_list)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = return_imputed_data(X_train, y_train_og, X_test, y_test_og)
# Out:
# X reshaped is (393, 36, 115)
# y reshaped is (393, 36, 1)
# (393, 36, 115) (393, 36, 1)
# X reshaped is (98, 36, 115)
# y reshaped is (98, 36, 1)
# (98, 36, 115) (98, 36, 1)

# %%
a,b,c,d = def_train_name(f_ix)

X_train.to_csv(a)
X_test.to_csv(b)
y_train.to_csv(c)
y_test.to_csv(d)

# %% [markdown]
# ## FIRST PART
# - FIRST IMPUTATION ONE TIME STEP AT A TIME
# - WE USE ONLY THE ORIGINAL TRAINING DATA and DO A VALIDATION SPLIT TO TUNE PARAMETERS
#
# ## SECOND PART
# - WE START THIS PART ONCE WE HAVE IMPUTED OUR WHOLE FEATURE SPACE
# - WE RUN OUR MODEL FOR 100 EPOCHS
# - WE EVALUATE ON THE DATA WE LEFT ASIDE

# %% [markdown]
# ORIGINAL TRAIN -> TRAINING and VALIDATION TO TUNE PARAMETERS
#
# ORIGINAL TEST -> FINAL VALUE
#
# The only thing that gets updated is the training operation with known training data
# but we impute for the testing data at each epoch once we have imputed the whole feature space
